# %% [markdown]
# <h2 style="color:green" align="center">Machine Learning With Python: Linear Regression With One Variable</h2>

# %% [markdown]
# **Problem Statement**: Predict India's per capita income in year 2023 using india_gdp.csv

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datasets/gdp/india_gdp.csv')
df
# Out:
#     year          gdp
# 0   1960    81.284764
# 1   1961    84.426437
# 2   1962    88.914919
# 3   1963   100.048592
# 4   1964   114.315161
# 5   1965   118.063382
# 6   1966    89.053583
# 7   1967    95.330783
# 8   1968    98.831235
# 9   1969   106.496379
# 10  1970   111.257571
# 11  1971   117.360738
# 12  1972   121.692289
# 13  1973   142.270081
# 14  1974   161.763011
# 15  1975   156.380095
# 16  1976   159.407798
# 17  1977   184.272875
# 18  1978   203.558705
# 19  1979   221.687947
# 20  1980   263.840720
# 21  1981   267.711010
# 22  1982   271.333596
# 23  1983   288.307170
# 24  1984   273.901827
# 25  1985   293.488647
# 26  1986   307.395346
# 27  1987   337.063996
# 28  1988   350.672739
# 29  1989   342.723898
# 30  1990   363.964087
# 31  1991   300.096637
# 32  1992   313.860110
# 33  1993   298.217664
# 34  1994   342.717519
# 35  1995   370.101355
# 36  1996   396.014612
# 37  1997   411.387721
# 38  1998   409.194386
# 39  1999   437.586118
# 40  2000   438.864630
# 41  2001   447.013897
# 42  2002   466.200804
# 43  2003   541.135228
# 44  2004   621.318377
# 45  2005   707.008019
# 46  2006   792.025970
# 47  2007  1018.166373
# 48  2008   991.484630
# 49  2009  1090.317765
# 50  2010  1345.770153
# 51  2011  1461.671957
# 52  2012  1446.985410
# 53  2013  1452.195373
# 54  2014  1576.004018
# 55  2015  1606.038285
# 56  2016  1717.473878
# 57  2017  1939.612984

# %%
# %matplotlib inline
plt.xlabel('Year')
plt.ylabel('GDP (US$)')
plt.scatter(df.year,df.gdp,color='red',marker='+')

# %%
year = df[['year']]
year
# Out:
#     year
# 0   1960
# 1   1961
# 2   1962
# 3   1963
# 4   1964
# 5   1965
# 6   1966
# 7   1967
# 8   1968
# 9   1969
# 10  1970
# 11  1971
# 12  1972
# 13  1973
# 14  1974
# 15  1975
# 16  1976
# 17  1977
# 18  1978
# 19  1979
# 20  1980
# 21  1981
# 22  1982
# 23  1983
# 24  1984
# 25  1985
# 26  1986
# 27  1987
# 28  1988
# 29  1989
# 30  1990
# 31  1991
# 32  1992
# 33  1993
# 34  1994
# 35  1995
# 36  1996
# 37  1997
# 38  1998
# 39  1999
# 40  2000
# 41  2001
# 42  2002
# 43  2003
# 44  2004
# 45  2005
# 46  2006
# 47  2007
# 48  2008
# 49  2009
# 50  2010
# 51  2011
# 52  2012
# 53  2013
# 54  2014
# 55  2015
# 56  2016
# 57  2017

# %%
gdp = df.gdp
gdp
# Out:
# 0       81.284764
# 1       84.426437
# 2       88.914919
# 3      100.048592
# 4      114.315161
# 5      118.063382
# 6       89.053583
# 7       95.330783
# 8       98.831235
# 9      106.496379
# 10     111.257571
# 11     117.360738
# 12     121.692289
# 13     142.270081
# 14     161.763011
# 15     156.380095
# 16     159.407798
# 17     184.272875
# 18     203.558705
# 19     221.687947
# 20     263.840720
# 21     267.711010
# 22     271.333596
# 23     288.307170
# 24     273.901827
# 25     293.488647
# 26     307.395346
# 27     337.063996
# 28     350.672739
# 29     342.723898
# 30     363.964087
# 31     300.096637
# 32     313.860110
# 33     298.217664
# 34     342.717519
# 35     370.101355
# 36     396.014612
# 37     411.387721
# 38     409.194386
# 39     437.586118
# 40     438.864630
# 41     447.013897
# 42     466.200804
# 43     541.135228
# 44     621.318377
# 45     707.008019
# 46     792.025970
# 47    1018.166373
# 48     991.484630
# 49    1090.317765
# 50    1345.770153
# 51    1461.671957
# 52    1446.985410
# 53    1452.195373
# 54    1576.004018
# 55    1606.038285
# 56    1717.473878
# 57    1939.612984
# Name: gdp, dtype: float64

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(year,gdp)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.predict([[2023]])
# Out:
# array([1356.13563446])

# %%
reg.coef_
# Out:
# array([24.88784785])

# %%
reg.intercept_
# Out:
# -48991.980562837736

# %%
year_df = pd.read_csv("../datasets/year.csv")
year_df.head(3)
# Out:
#    year
# 0  2018
# 1  2019
# 2  2020

# %%
p = reg.predict(year_df)
p
# Out:
# array([1231.69639521, 1256.58424306, 1281.47209091, 1306.35993876,
#        1331.24778661, 1356.13563446, 1381.0234823 , 1405.91133015,
#        1455.68702585, 1480.5748737 , 1505.46272155, 1530.35056939])

# %%
year_df['income']=p
year_df
# Out:
#     year       income
# 0   2018  1231.696395
# 1   2019  1256.584243
# 2   2020  1281.472091
# 3   2021  1306.359939
# 4   2022  1331.247787
# 5   2023  1356.135634
# 6   2024  1381.023482
# 7   2025  1405.911330
# 8   2027  1455.687026
# 9   2028  1480.574874
# 10  2029  1505.462722
# 11  2030  1530.350569

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(year,gdp,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(x_train, y_train)  
lr = LinearRegression().fit(x_train, y_train)

# %%
y_pred = regressor.predict([[2023]])
#y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([1445.43840416])

# %%
year_df = pd.read_csv("../datasets/year.csv")
year_df.head(3)
# Out:
#    year
# 0  2018
# 1  2019
# 2  2020

# %%
q = regressor.predict(year_df)
q
# Out:
# array([1311.12884284, 1337.9907551 , 1364.85266737, 1391.71457963,
#        1418.5764919 , 1445.43840416, 1472.30031643, 1499.16222869,
#        1552.88605323, 1579.74796549, 1606.60987776, 1633.47179002])

# %%
year_df['income']=q
year_df
# Out:
#     year       income
# 0   2018  1311.128843
# 1   2019  1337.990755
# 2   2020  1364.852667
# 3   2021  1391.714580
# 4   2022  1418.576492
# 5   2023  1445.438404
# 6   2024  1472.300316
# 7   2025  1499.162229
# 8   2027  1552.886053
# 9   2028  1579.747965
# 10  2029  1606.609878
# 11  2030  1633.471790

# %%
print("Training set score: {:.2f}".format(lr.score(x_train, y_train)))
print("Test set score: {:.7f}".format(lr.score(x_test, y_test)))
# Out:
# Training set score: 0.76
# Test set score: 0.0616370

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline


steps = [
    ('poly', PolynomialFeatures(degree=2)),
    ('model', LinearRegression())
]

pipeline = Pipeline(steps)

pipeline.fit(x_train, y_train)

print('Training score: {}'.format(pipeline.score(x_train, y_train)))
print('Test score: {}'.format(pipeline.score(x_test, y_test)))
# Out:
# Training score: 0.9387553972682393
# Test score: 0.7188532290858168

# %%
pipeline.predict([[2023]])
# Out:
# array([2188.9340634])

# %%
# Now Read Years
year_f = pd.read_csv("../datasets/year.csv")
year_f.head(3)
# Out:
#    year
# 0  2018
# 1  2019
# 2  2020

# %%
qr = pipeline.predict(year_f)
qr
# Out:
# array([1780.16999507, 1858.40128097, 1938.39333076, 2020.14614443,
#        2103.65972197, 2188.9340634 , 2275.9691687 , 2364.76503789,
#        2547.63906791, 2641.71722873, 2737.55615344, 2835.15584203])

# %%
year_f['gdp']=qr
print('Forecast per capita GDP (US$) : ')
year_f
# Out:
# Forecast per capita GDP (US$) :
#     year          gdp
# 0   2018  1780.169995
# 1   2019  1858.401281
# 2   2020  1938.393331
# 3   2021  2020.146144
# 4   2022  2103.659722
# 5   2023  2188.934063
# 6   2024  2275.969169
# 7   2025  2364.765038
# 8   2027  2547.639068
# 9   2028  2641.717229
# 10  2029  2737.556153
# 11  2030  2835.155842

# %%
# %matplotlib inline
plt.xlabel('Year')
plt.ylabel('GDP (US$)')
plt.plot(df.year,df.gdp,color='g',marker='+')
plt.plot(year_f.year,qr,color='red',marker='+')
